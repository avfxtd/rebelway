# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/media/anthony/nvme1/RebelWayMachineLearning/Coursework/CarPrice_Assignment.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# Cleanup

# %%
df.drop(["car_ID","symboling","stroke","boreratio","compressionratio","peakrpm"], axis=1, inplace=True)

# %%
# Make a new column with the car brand
# Seems that this might be useful
df[['CarBrand', 'CarModel']] = df['CarName'].str.split(' ', n=1, expand=True)

# %%
df.head()
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginetype  \
# 0        rwd          front       88.6      168.8      64.1  ...        dohc
# 1        rwd          front       88.6      168.8      64.1  ...        dohc
# 2        rwd          front       94.5      171.2      65.5  ...        ohcv
# 3        fwd          front       99.8      176.6      66.2  ...         ohc
# 4        4wd          front       99.4      176.6      66.4  ...         ohc
#
# ...

# %%
sns.set()
plt.figure(figsize=(15,12))
sns.pairplot(df)
plt.show()
# Out:
# /home/anthony/Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/anthony/Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/anthony/Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="enginetype",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='enginetype', ylabel='price'>

# %%
sns.lmplot(x="enginesize", y="price", data=df)

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x="carbody",y="price",data=df,palette="husl")
# Out:
# <Axes: xlabel='carbody', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.violinplot(data=df, x="carbody", y="price", hue="fueltype",
               split=True, fill=False,)
# Out:
# <Axes: xlabel='carbody', ylabel='price'>

# %%
plt.figure(figsize=(25,6))
sns.boxplot(x="CarBrand",y="price",data=df,palette="Spectral")
# Out:
# <Axes: xlabel='CarBrand', ylabel='price'>

# %%
plt.figure(figsize=(12,12))
sns.boxplot(x="price",y="CarBrand",data=df,palette="Spectral")
# Out:
# <Axes: xlabel='price', ylabel='CarBrand'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="cylindernumber",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='cylindernumber', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="fuelsystem",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='fuelsystem', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="fueltype",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='fueltype', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="enginelocation",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='enginelocation', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="highwaympg",y="price",data=df,palette="Spectral")
# Out:
# <Axes: xlabel='highwaympg', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="citympg",y="price",data=df,palette="Spectral")
# Out:
# <Axes: xlabel='citympg', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="citympg",y="price",data=df,hue="fueltype")
# Out:
# <Axes: xlabel='citympg', ylabel='price'>

# %%
# Convert categorical columns to numerical values using label encoding or one-hot encoding
le = LabelEncoder()
df['carbody'] = le.fit_transform(df['carbody'])

# %%
df.head()
# Out:
#                     CarName fueltype aspiration doornumber  carbody  \
# 0        alfa-romero giulia      gas        std        two        0
# 1       alfa-romero stelvio      gas        std        two        0
# 2  alfa-romero Quadrifoglio      gas        std        two        2
# 3               audi 100 ls      gas        std       four        3
# 4                audi 100ls      gas        std       four        3
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginetype  \
# 0        rwd          front       88.6      168.8      64.1  ...        dohc
# 1        rwd          front       88.6      168.8      64.1  ...        dohc
# 2        rwd          front       94.5      171.2      65.5  ...        ohcv
# 3        fwd          front       99.8      176.6      66.2  ...         ohc
# 4        4wd          front       99.4      176.6      66.4  ...         ohc
#
#    cylindernumber enginesize fuelsystem  horsepower citympg  highwaympg  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="carbody",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='carbody', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="carheight",y="price",data=df,palette="winter")
# Out:
# <Axes: xlabel='carheight', ylabel='price'>

# %%
df.head()
# Out:
#                     CarName fueltype aspiration doornumber  carbody  \
# 0        alfa-romero giulia      gas        std        two        0
# 1       alfa-romero stelvio      gas        std        two        0
# 2  alfa-romero Quadrifoglio      gas        std        two        2
# 3               audi 100 ls      gas        std       four        3
# 4                audi 100ls      gas        std       four        3
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginetype  \
# 0        rwd          front       88.6      168.8      64.1  ...        dohc
# 1        rwd          front       88.6      168.8      64.1  ...        dohc
# 2        rwd          front       94.5      171.2      65.5  ...        ohcv
# 3        fwd          front       99.8      176.6      66.2  ...         ohc
# 4        4wd          front       99.4      176.6      66.4  ...         ohc
#
#    cylindernumber enginesize fuelsystem  horsepower citympg  highwaympg  \
# ...

# %% [markdown]
# # Here i am converting the object strings to booleans, though not sure this is entirely correct

# %%
categorical_cols = ['carbody', 'fueltype','cylindernumber','CarBrand','enginelocation','aspiration']
#categorical_cols = ['fueltype','cylindernumber','CarBrand']

# %%
encoded_df = pd.get_dummies(df, columns=categorical_cols)

# %%
encoded_df.head()
# Out:
#                     CarName doornumber drivewheel  wheelbase  carlength  \
# 0        alfa-romero giulia        two        rwd       88.6      168.8
# 1       alfa-romero stelvio        two        rwd       88.6      168.8
# 2  alfa-romero Quadrifoglio        two        rwd       94.5      171.2
# 3               audi 100 ls       four        fwd       99.8      176.6
# 4                audi 100ls       four        4wd       99.4      176.6
#
#    carwidth  carheight  curbweight enginetype  enginesize  ...  \
# 0      64.1       48.8        2548       dohc         130  ...
# 1      64.1       48.8        2548       dohc         130  ...
# 2      65.5       52.4        2823       ohcv         152  ...
# 3      66.2       54.3        2337        ohc         109  ...
# 4      66.4       54.3        2824        ohc         136  ...
#
#   CarBrand_toyota  CarBrand_toyouta  CarBrand_vokswagen  CarBrand_volkswagen  \
# ...

# %% [markdown]
# # adding back numerical columns

# %%
numeric_cols = ['citympg','highwaympg','enginesize','horsepower','carwidth','carheight']
#numeric_cols = ['citympg','highwaympg','enginesize','horsepower']

# %%
train_cols = categorical_cols + numeric_cols

# %%
X = pd.get_dummies(df[train_cols])
y = df["price"]

# %%
X.head()
# Out:
#    carbody  citympg  highwaympg  enginesize  horsepower  carwidth  carheight  \
# 0        0       21          27         130         111      64.1       48.8
# 1        0       21          27         130         111      64.1       48.8
# 2        2       19          26         152         154      65.5       52.4
# 3        3       24          30         109         102      66.2       54.3
# 4        3       18          22         136         115      66.4       54.3
#
#    fueltype_diesel  fueltype_gas  cylindernumber_eight  ...  CarBrand_toyota  \
# 0            False          True                 False  ...            False
# 1            False          True                 False  ...            False
# 2            False          True                 False  ...            False
# 3            False          True                 False  ...            False
# 4            False          True                 False  ...            False
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5, random_state=101)

# %%
#X_train

# %%
from sklearn.metrics import classification_report

linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Coef: ", linear_model.coef_)
# Out:
# Coef:  [ 1.71838705e+02 -1.00384680e+02  1.22189247e+02  2.12453230e+01
#   4.17488605e+01  1.03549880e+03  3.99665502e+01  1.82240866e+02
#  -1.82240866e+02  4.47066181e+03 -2.03766571e+03 -2.26447735e+03
#  -8.57000756e+02 -3.63797881e-12 -2.93414164e+03  3.62262365e+03
#  -7.27595761e-12  2.74349798e+03  4.86951498e+02  7.70213037e+03
#   6.85118206e+03 -2.04321453e+03 -2.26442200e+03 -9.76866630e+02
#   3.52366121e+02  8.66252427e+03 -3.03201834e+03 -3.11277508e+03
#  -2.93999057e+03 -3.27444717e+03 -2.28357666e+03 -4.02892271e+02
#  -2.39118230e+03  8.56979699e+02  5.52881840e+03 -4.33859208e+03
#   4.87806559e+02 -2.65421347e+03 -1.72822274e+03 -2.16485863e+03
#   0.00000000e+00 -1.82808507e+03 -8.47283766e+01  1.84782896e+03
#  -6.38579810e+03  6.38579810e+03 -6.75492296e+02  6.75492296e+02]

# %%
predictions = linear_model.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel("Y test")
plt.ylabel("Predicted Y")
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

# %%
print("MAE: ", metrics.mean_absolute_error(y_test,predictions))
print("MSE: ", metrics.mean_squared_error(y_test,predictions))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE:  1655.986435862209
# MSE:  6789087.5607818235
# RMSE:  2605.5877572597365

# %%
sns.displot((y_test-predictions), bins=100, kde=True)
# Out:
# /home/anthony/Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.head()
# Out:
#                     CarName fueltype aspiration doornumber  carbody  \
# 0        alfa-romero giulia      gas        std        two        0
# 1       alfa-romero stelvio      gas        std        two        0
# 2  alfa-romero Quadrifoglio      gas        std        two        2
# 3               audi 100 ls      gas        std       four        3
# 4                audi 100ls      gas        std       four        3
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginetype  \
# 0        rwd          front       88.6      168.8      64.1  ...        dohc
# 1        rwd          front       88.6      168.8      64.1  ...        dohc
# 2        rwd          front       94.5      171.2      65.5  ...        ohcv
# 3        fwd          front       99.8      176.6      66.2  ...         ohc
# 4        4wd          front       99.4      176.6      66.4  ...         ohc
#
#    cylindernumber enginesize fuelsystem  horsepower citympg  highwaympg  \
# ...

# %%
set(df['CarBrand'].values)
# Out:
# {'Nissan',
#  'alfa-romero',
#  'audi',
#  'bmw',
#  'buick',
#  'chevrolet',
#  'dodge',
#  'honda',
#  'isuzu',
#  'jaguar',
#  'maxda',
#  'mazda',
#  'mercury',
#  'mitsubishi',
#  'nissan',
#  'peugeot',
#  'plymouth',
#  'porcshce',
#  'porsche',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'toyouta',
#  'vokswagen',
#  'volkswagen',
#  'volvo',
#  'vw'}

# %%
train_cols
# Out:
# ['carbody',
#  'fueltype',
#  'cylindernumber',
#  'CarBrand',
#  'enginelocation',
#  'aspiration',
#  'citympg',
#  'highwaympg',
#  'enginesize',
#  'horsepower',
#  'carwidth',
#  'carheight']

# %%
categorical_cols
# Out:
# ['carbody',
#  'fueltype',
#  'cylindernumber',
#  'CarBrand',
#  'enginelocation',
#  'aspiration']

# %%
new_car_data = {'fueltype':['gas'],
 'cylindernumber':['four'],
 'CarBrand':['honda'],
 'citympg':[25],
 'highwaympg':[35],
 'enginesize':[100],
 'horsepower':[100]}

df_pred = pd.DataFrame(data)
cols = list(new_car_data.keys())

# %%
cols
# Out:
# ['fueltype',
#  'cylindernumber',
#  'CarBrand',
#  'citympg',
#  'highwaympg',
#  'enginesize',
#  'horsepower']

# %%
categorical_cols
# Out:
# ['carbody',
#  'fueltype',
#  'cylindernumber',
#  'CarBrand',
#  'enginelocation',
#  'aspiration']

# %%
encoded_new_car_data = pd.get_dummies(df_pred, columns=categorical_cols)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1664], line 1
# ----> 1 encoded_new_car_data = pd.get_dummies(df_pred, columns=categorical_cols)
#
# File ~/Applications/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File ~/Applications/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
encoded_new_car_data

# %%
new_predictions = linear_model.predict(encoded_new_car_data)
